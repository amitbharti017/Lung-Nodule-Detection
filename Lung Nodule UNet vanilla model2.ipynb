# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
import random
from tqdm import tqdm
import cv2
from skimage.io import imread,imshow
from skimage.transform import resize
from tensorflow.keras import backend as K
import tensorflow_addons as tfa
# Out:
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:67: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   UserWarning,

# %%
# from tensorflow.python.ops.numpy_ops import np_config
# np_config.enable_numpy_behavior()

# %%
TRAIN_PATH = "dataset/2d_slices/pre_processed_images/"
TRAIN_MASK_PATH = "dataset/2d_slices/masks/"
MODEL_SAVE = "model/"

# %%
train_ids = next(os.walk(TRAIN_PATH))[2]
mask_train_ids = next(os.walk(TRAIN_MASK_PATH))[2]

# %%
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

# %%
X_train = np.zeros((len(train_ids),IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_train=np.zeros((len(mask_train_ids),IMG_HEIGHT,IMG_WIDTH,1),dtype = np.float16)

# %%
for n,id_ in tqdm(enumerate(train_ids),total=len(train_ids)):
    path=TRAIN_PATH+"/"+id_
    img = np.load(path)
    img = resize(img,(IMG_HEIGHT,IMG_WIDTH),mode="constant",preserve_range=True)
    X_train[n]=np.expand_dims(img, axis=2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1176/1176 [00:23<00:00, 50.79it/s]

# %%
for n,id_ in tqdm(enumerate(mask_train_ids),total=len(mask_train_ids)):
    path=TRAIN_MASK_PATH+"/"+id_
    mask = np.load(path)
    mask = resize(mask,(IMG_HEIGHT,IMG_WIDTH),mode="constant",preserve_range=True)
    Y_train[n]=np.expand_dims(mask, axis=2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1176/1176 [00:22<00:00, 51.21it/s]

# %%
#Checking the training data
ix=random.randint(0,len(train_ids))
plt.figure(figsize=[20,10])
plt.subplot(131)
imshow(X_train[ix])
plt.subplot(132)
imshow(Y_train[ix])
plt.subplot(133)
imshow((X_train[ix])*Y_train[ix])
smallest = X_train[ix].min(axis=(0, 1))
largest = X_train[ix].max(axis=(0, 1))
print("Smallest pixel in image is",smallest)
print("Largest pixel in image is", largest)
smallest = Y_train[ix].min(axis=(0, 1))
largest = Y_train[ix].max(axis=(0, 1))
print("Smallest pixel in mask is",smallest)
print("Largest pixel in mask is", largest)
# Out:
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Smallest pixel in image is [24]
# Largest pixel in image is [255]
# Smallest pixel in mask is [0.]
# Largest pixel in mask is [1.]

# %%
#https://stackoverflow.com/questions/72195156/correct-implementation-of-dice-loss-in-tensorflow-keras
# def dice_coef(y_true, y_pred, smooth = 100):        
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum(y_true_f * y_pred_f)
#     dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
#     return dice
def dice_coef(y_true, y_pred, smooth = 1e-5):
    intersection = tf.reduce_sum(tf.multiply(y_true, y_pred), axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    dice_scores_tensor = (2. * intersection + smooth) / (union + smooth)
    mean_dice_score = tf.reduce_mean(dice_scores_tensor)
    return mean_dice_score

# %%
def dice_coef_loss_and_bce(y_true, y_pred):
    dice_loss = 1- dice_coef(y_true, y_pred) 
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    term_0 = (1 - y_true) * K.log(1 - y_pred + K.epsilon())  
    term_1 = y_true * K.log(y_pred + K.epsilon())
    bce_loss = -K.mean(term_0 + term_1, axis=0)
    mean = 0.5*(dice_loss + bce_loss)
    return mean

# %%
inputs = tf.keras.layers.Input((IMG_WIDTH,IMG_HEIGHT,IMG_CHANNELS))

# %%
s = tf.keras.layers.Lambda(lambda x:x / 255)(inputs)

# %% [markdown]
# ### Constructing U NET

# %%
c1 = tf.keras.layers.Conv2D(16,(3,3),activation="relu",kernel_initializer = "he_normal",padding="same")(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c1)
p1=tf.keras.layers.MaxPooling2D((2,2))(c1)

# %%
c2=tf.keras.layers.Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2=tf.keras.layers.Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c2)
p2= tf.keras.layers.MaxPooling2D((2,2))(c2)

# %%
c3=tf.keras.layers.Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p2)
c3=tf.keras.layers.Dropout(0.2)(c3)
c3=tf.keras.layers.Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c3)
p3=tf.keras.layers.MaxPooling2D((2,2))(c3)

# %%
c4=tf.keras.layers.Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p3)
c4=tf.keras.layers.Dropout(0.2)(c4)
c4=tf.keras.layers.Conv2D(126,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c4)
p4=tf.keras.layers.MaxPooling2D((2,2))(c4)

# %%
c5=tf.keras.layers.Conv2D(256,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p4)
c5=tf.keras.layers.Dropout(0.3)(c5)
c5=tf.keras.layers.Conv2D(256,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c5)
p5=tf.keras.layers.MaxPooling2D((2,2))(c5)

# %%
#expansive path

# %%
u6 = tf.keras.layers.Conv2DTranspose(128,(2,2),strides=(2,2),padding="same")(c5)
u6=tf.keras.layers.concatenate([u6,c4])
c6=tf.keras.layers.Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u6)
c6=tf.keras.layers.Dropout(0.2)(c6)
c6=tf.keras.layers.Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c6)

# %%
u7=tf.keras.layers.Conv2DTranspose(64,(2,2),strides=(2,2),padding="same")(c6)
u7=tf.keras.layers.concatenate([u7,c3])
c7=tf.keras.layers.Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u7)
c7=tf.keras.layers.Dropout(0.2)(c7)
c7=tf.keras.layers.Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c7)

# %%
u8 = tf.keras.layers.Conv2DTranspose(32,(2,2),strides=(2,2),padding="same")(c7)
u8=tf.keras.layers.concatenate([u8,c2])
c8=tf.keras.layers.Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u8)
c8=tf.keras.layers.Dropout(0.1)(c8)
c8=tf.keras.layers.Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c8)

# %%
u9=tf.keras.layers.Conv2DTranspose(16,(2,2),strides=(2,2),padding="same")(c8)
u9=tf.keras.layers.concatenate([u9,c1],axis=3)
c9=tf.keras.layers.Conv2D(16,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u9)
c9=tf.keras.layers.Dropout(0.1)(c9)
c9=tf.keras.layers.Conv2D(16,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c9)

# %%
outputs=tf.keras.layers.Conv2D(1,(1,1),activation="sigmoid")(c9)

# %%
#https://towardsdatascience.com/dealing-with-class-imbalanced-image-datasets-1cbd17de76b5
model_unet=tf.keras.Model(inputs=[inputs],outputs=[outputs])
model_unet.compile(optimizer=tf.keras.optimizers.Adam(lr=0.00001),loss=dice_coef_loss_and_bce,metrics=[dice_coef])
model_unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 16  160         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 512, 512, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 256, 256, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 32  9248        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d_1[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 128, 128, 64  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  36928       ['dropout_2[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 126)  145278      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 126)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 256)  290560      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 32, 32, 256)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 256)  590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 254)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 128)  292736      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_11[0][0]']
#  spose)                         )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_1[0][0]',
#                                 8)                                'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_1[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 128, 128, 64  0           ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_6[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 256, 256, 32  0           ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_7[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 512, 512, 16  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,931,599
# Trainable params: 1,931,599
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\Users\amit\AppData\Roaming\Python\Python37\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
checkpointer= tf.keras.callbacks.ModelCheckpoint("./lungnodule_vanilla_model2.h5",verbose=1,save_best_only=True)

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
callbacks=[
    tf.keras.callbacks.EarlyStopping(patience=30,monitor="dice_coef"),
    tf.keras.callbacks.TensorBoard(log_dir="logs"),
    checkpointer
]

# %%
 results = model_unet.fit(X_train,Y_train,validation_split=0.25,batch_size=64,epochs=1000,callbacks=callbacks )
# Out:
# Epoch 1/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9981 - dice_coef: 0.0019
# Epoch 1: val_loss improved from inf to 0.99792, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1255s 45s/step - loss: 0.9981 - dice_coef: 0.0019 - val_loss: 0.9979 - val_dice_coef: 0.0022
# Epoch 2/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9978 - dice_coef: 0.0022
# Epoch 2: val_loss did not improve from 0.99792
# 28/28 [==============================] - 1141s 41s/step - loss: 0.9978 - dice_coef: 0.0022 - val_loss: 0.9982 - val_dice_coef: 0.0018
# Epoch 3/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9972 - dice_coef: 0.0028
# Epoch 3: val_loss did not improve from 0.99792
# 28/28 [==============================] - 1039s 37s/step - loss: 0.9972 - dice_coef: 0.0028 - val_loss: 0.9979 - val_dice_coef: 0.0020
# Epoch 4/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9961 - dice_coef: 0.0040
# Epoch 4: val_loss improved from 0.99792 to 0.99556, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1109s 40s/step - loss: 0.9961 - dice_coef: 0.0040 - val_loss: 0.9956 - val_dice_coef: 0.0044
# Epoch 5/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9926 - dice_coef: 0.0074
# Epoch 5: val_loss improved from 0.99556 to 0.98950, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1282s 46s/step - loss: 0.9926 - dice_coef: 0.0074 - val_loss: 0.9895 - val_dice_coef: 0.0105
# Epoch 6/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9841 - dice_coef: 0.0159
# Epoch 6: val_loss improved from 0.98950 to 0.97650, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1148s 41s/step - loss: 0.9841 - dice_coef: 0.0159 - val_loss: 0.9765 - val_dice_coef: 0.0230
# Epoch 7/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9660 - dice_coef: 0.0346
# Epoch 7: val_loss improved from 0.97650 to 0.97483, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1068s 38s/step - loss: 0.9660 - dice_coef: 0.0346 - val_loss: 0.9748 - val_dice_coef: 0.0247
# Epoch 8/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9537 - dice_coef: 0.0465
# Epoch 8: val_loss did not improve from 0.97483
# 28/28 [==============================] - 1155s 41s/step - loss: 0.9537 - dice_coef: 0.0465 - val_loss: 0.9795 - val_dice_coef: 0.0202
# Epoch 9/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9398 - dice_coef: 0.0599
# Epoch 9: val_loss improved from 0.97483 to 0.97077, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1201s 43s/step - loss: 0.9398 - dice_coef: 0.0599 - val_loss: 0.9708 - val_dice_coef: 0.0286
# Epoch 10/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9184 - dice_coef: 0.0819
# Epoch 10: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1259s 45s/step - loss: 0.9184 - dice_coef: 0.0819 - val_loss: 0.9787 - val_dice_coef: 0.0209
# Epoch 11/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9150 - dice_coef: 0.0850
# Epoch 11: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1311s 47s/step - loss: 0.9150 - dice_coef: 0.0850 - val_loss: 0.9939 - val_dice_coef: 0.0061
# Epoch 12/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9035 - dice_coef: 0.0961
# Epoch 12: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1285s 46s/step - loss: 0.9035 - dice_coef: 0.0961 - val_loss: 0.9928 - val_dice_coef: 0.0072
# Epoch 13/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8980 - dice_coef: 0.1014
# Epoch 13: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1186s 42s/step - loss: 0.8980 - dice_coef: 0.1014 - val_loss: 0.9883 - val_dice_coef: 0.0115
# Epoch 14/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9076 - dice_coef: 0.0928
# Epoch 14: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1084s 39s/step - loss: 0.9076 - dice_coef: 0.0928 - val_loss: 0.9823 - val_dice_coef: 0.0174
# Epoch 15/200
# 28/28 [==============================] - ETA: 0s - loss: 0.9006 - dice_coef: 0.0990
# Epoch 15: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1052s 38s/step - loss: 0.9006 - dice_coef: 0.0990 - val_loss: 0.9937 - val_dice_coef: 0.0063
# Epoch 16/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8856 - dice_coef: 0.1138
# Epoch 16: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1234s 44s/step - loss: 0.8856 - dice_coef: 0.1138 - val_loss: 0.9875 - val_dice_coef: 0.0123
# Epoch 17/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8781 - dice_coef: 0.1227
# Epoch 17: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1367s 49s/step - loss: 0.8781 - dice_coef: 0.1227 - val_loss: 0.9947 - val_dice_coef: 0.0053
# Epoch 18/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8819 - dice_coef: 0.1179
# Epoch 18: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1038s 37s/step - loss: 0.8819 - dice_coef: 0.1179 - val_loss: 0.9931 - val_dice_coef: 0.0068
# Epoch 19/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8738 - dice_coef: 0.1262
# Epoch 19: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1002s 36s/step - loss: 0.8738 - dice_coef: 0.1262 - val_loss: 0.9955 - val_dice_coef: 0.0045
# Epoch 20/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8737 - dice_coef: 0.1263
# Epoch 20: val_loss did not improve from 0.97077
# 28/28 [==============================] - 997s 36s/step - loss: 0.8737 - dice_coef: 0.1263 - val_loss: 0.9962 - val_dice_coef: 0.0038
# Epoch 21/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8710 - dice_coef: 0.1282
# Epoch 21: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1008s 36s/step - loss: 0.8710 - dice_coef: 0.1282 - val_loss: 0.9934 - val_dice_coef: 0.0066
# Epoch 22/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8649 - dice_coef: 0.1357
# Epoch 22: val_loss did not improve from 0.97077
# 28/28 [==============================] - 994s 36s/step - loss: 0.8649 - dice_coef: 0.1357 - val_loss: 0.9966 - val_dice_coef: 0.0034
# Epoch 23/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8643 - dice_coef: 0.1346
# Epoch 23: val_loss did not improve from 0.97077
# 28/28 [==============================] - 995s 36s/step - loss: 0.8643 - dice_coef: 0.1346 - val_loss: 0.9960 - val_dice_coef: 0.0040
# Epoch 24/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8668 - dice_coef: 0.1337
# Epoch 24: val_loss did not improve from 0.97077
# 28/28 [==============================] - 999s 36s/step - loss: 0.8668 - dice_coef: 0.1337 - val_loss: 0.9918 - val_dice_coef: 0.0081
# Epoch 25/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8562 - dice_coef: 0.1429
# Epoch 25: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1004s 36s/step - loss: 0.8562 - dice_coef: 0.1429 - val_loss: 0.9902 - val_dice_coef: 0.0096
# Epoch 26/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8546 - dice_coef: 0.1457
# Epoch 26: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1002s 36s/step - loss: 0.8546 - dice_coef: 0.1457 - val_loss: 0.9961 - val_dice_coef: 0.0039
# Epoch 27/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8576 - dice_coef: 0.1418
# Epoch 27: val_loss did not improve from 0.97077
# 28/28 [==============================] - 993s 36s/step - loss: 0.8576 - dice_coef: 0.1418 - val_loss: 0.9852 - val_dice_coef: 0.0145
# Epoch 28/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8580 - dice_coef: 0.1421
# Epoch 28: val_loss did not improve from 0.97077
# 28/28 [==============================] - 998s 36s/step - loss: 0.8580 - dice_coef: 0.1421 - val_loss: 0.9913 - val_dice_coef: 0.0086
# Epoch 29/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8531 - dice_coef: 0.1466
# Epoch 29: val_loss did not improve from 0.97077
# 28/28 [==============================] - 998s 36s/step - loss: 0.8531 - dice_coef: 0.1466 - val_loss: 0.9952 - val_dice_coef: 0.0048
# Epoch 30/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8494 - dice_coef: 0.1500
# Epoch 30: val_loss did not improve from 0.97077
# 28/28 [==============================] - 994s 36s/step - loss: 0.8494 - dice_coef: 0.1500 - val_loss: 0.9917 - val_dice_coef: 0.0082
# Epoch 31/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8486 - dice_coef: 0.1511
# Epoch 31: val_loss did not improve from 0.97077
# 28/28 [==============================] - 995s 36s/step - loss: 0.8486 - dice_coef: 0.1511 - val_loss: 0.9916 - val_dice_coef: 0.0083
# Epoch 32/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8449 - dice_coef: 0.1541
# Epoch 32: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1006s 36s/step - loss: 0.8449 - dice_coef: 0.1541 - val_loss: 0.9874 - val_dice_coef: 0.0125
# Epoch 33/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8395 - dice_coef: 0.1614
# Epoch 33: val_loss did not improve from 0.97077
# 28/28 [==============================] - 997s 36s/step - loss: 0.8395 - dice_coef: 0.1614 - val_loss: 0.9915 - val_dice_coef: 0.0084
# Epoch 34/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8409 - dice_coef: 0.1580
# Epoch 34: val_loss did not improve from 0.97077
# 28/28 [==============================] - 997s 36s/step - loss: 0.8409 - dice_coef: 0.1580 - val_loss: 0.9877 - val_dice_coef: 0.0121
# Epoch 35/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8478 - dice_coef: 0.1517
# Epoch 35: val_loss did not improve from 0.97077
# 28/28 [==============================] - 996s 36s/step - loss: 0.8478 - dice_coef: 0.1517 - val_loss: 0.9902 - val_dice_coef: 0.0097
# Epoch 36/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8375 - dice_coef: 0.1608
# Epoch 36: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1001s 36s/step - loss: 0.8375 - dice_coef: 0.1608 - val_loss: 0.9789 - val_dice_coef: 0.0207
# Epoch 37/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8362 - dice_coef: 0.1641
# Epoch 37: val_loss did not improve from 0.97077
# 28/28 [==============================] - 993s 36s/step - loss: 0.8362 - dice_coef: 0.1641 - val_loss: 0.9741 - val_dice_coef: 0.0254
# Epoch 38/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8351 - dice_coef: 0.1645
# Epoch 38: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1072s 38s/step - loss: 0.8351 - dice_coef: 0.1645 - val_loss: 0.9818 - val_dice_coef: 0.0179
# Epoch 39/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8405 - dice_coef: 0.1606
# Epoch 39: val_loss did not improve from 0.97077
# 28/28 [==============================] - 1042s 37s/step - loss: 0.8405 - dice_coef: 0.1606 - val_loss: 0.9757 - val_dice_coef: 0.0239
# Epoch 40/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8398 - dice_coef: 0.1602
# Epoch 40: val_loss improved from 0.97077 to 0.96459, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1031s 37s/step - loss: 0.8398 - dice_coef: 0.1602 - val_loss: 0.9646 - val_dice_coef: 0.0344
# Epoch 41/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8359 - dice_coef: 0.1626
# Epoch 41: val_loss did not improve from 0.96459
# 28/28 [==============================] - 1068s 38s/step - loss: 0.8359 - dice_coef: 0.1626 - val_loss: 0.9844 - val_dice_coef: 0.0154
# Epoch 42/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8306 - dice_coef: 0.1692
# Epoch 42: val_loss improved from 0.96459 to 0.96259, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 1078s 38s/step - loss: 0.8306 - dice_coef: 0.1692 - val_loss: 0.9626 - val_dice_coef: 0.0364
# Epoch 43/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8276 - dice_coef: 0.1725
# Epoch 43: val_loss did not improve from 0.96259
# 28/28 [==============================] - 1049s 37s/step - loss: 0.8276 - dice_coef: 0.1725 - val_loss: 0.9800 - val_dice_coef: 0.0197
# Epoch 44/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8231 - dice_coef: 0.1768
# Epoch 44: val_loss did not improve from 0.96259
# 28/28 [==============================] - 1010s 36s/step - loss: 0.8231 - dice_coef: 0.1768 - val_loss: 0.9763 - val_dice_coef: 0.0232
# Epoch 45/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8220 - dice_coef: 0.1774
# Epoch 45: val_loss did not improve from 0.96259
# 28/28 [==============================] - 988s 35s/step - loss: 0.8220 - dice_coef: 0.1774 - val_loss: 0.9812 - val_dice_coef: 0.0185
# Epoch 46/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8177 - dice_coef: 0.1831
# Epoch 46: val_loss improved from 0.96259 to 0.96244, saving model to ./model\lungnodule_vanilla.h5
# 28/28 [==============================] - 963s 34s/step - loss: 0.8177 - dice_coef: 0.1831 - val_loss: 0.9624 - val_dice_coef: 0.0365
# Epoch 47/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8160 - dice_coef: 0.1845
# Epoch 47: val_loss did not improve from 0.96244
# 28/28 [==============================] - 1350s 49s/step - loss: 0.8160 - dice_coef: 0.1845 - val_loss: 0.9783 - val_dice_coef: 0.0214
# Epoch 48/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8227 - dice_coef: 0.1773
# Epoch 48: val_loss did not improve from 0.96244
# 28/28 [==============================] - 1047s 37s/step - loss: 0.8227 - dice_coef: 0.1773 - val_loss: 0.9671 - val_dice_coef: 0.0321
# Epoch 49/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8142 - dice_coef: 0.1859
# Epoch 49: val_loss did not improve from 0.96244
# 28/28 [==============================] - 983s 35s/step - loss: 0.8142 - dice_coef: 0.1859 - val_loss: 0.9659 - val_dice_coef: 0.0333
# Epoch 50/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8168 - dice_coef: 0.1831
# Epoch 50: val_loss did not improve from 0.96244
# 28/28 [==============================] - 978s 35s/step - loss: 0.8168 - dice_coef: 0.1831 - val_loss: 0.9728 - val_dice_coef: 0.0264
# Epoch 51/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8250 - dice_coef: 0.1750
# Epoch 51: val_loss did not improve from 0.96244
# 28/28 [==============================] - 994s 36s/step - loss: 0.8250 - dice_coef: 0.1750 - val_loss: 0.9778 - val_dice_coef: 0.0218
# Epoch 52/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8173 - dice_coef: 0.1823
# Epoch 52: val_loss did not improve from 0.96244
# 28/28 [==============================] - 1034s 37s/step - loss: 0.8173 - dice_coef: 0.1823 - val_loss: 0.9769 - val_dice_coef: 0.0227
# Epoch 53/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8189 - dice_coef: 0.1816
# Epoch 53: val_loss did not improve from 0.96244
# 28/28 [==============================] - 1002s 36s/step - loss: 0.8189 - dice_coef: 0.1816 - val_loss: 0.9646 - val_dice_coef: 0.0346
# Epoch 54/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8130 - dice_coef: 0.1864
# Epoch 54: val_loss did not improve from 0.96244
# 28/28 [==============================] - 1144s 41s/step - loss: 0.8130 - dice_coef: 0.1864 - val_loss: 0.9675 - val_dice_coef: 0.0314
# Epoch 55/200
# 26/28 [==========================>...] - ETA: 1:22 - loss: 0.8140 - dice_coef: 0.1860

# %%
dice_coef = results.history['dice_coef']
val_dice_coef = results.history['val_dice_coef']
loss = results.history['loss']
val_loss = results.history['val_loss']
import matplotlib.pyplot as plt
epochs = range(1, len(dice_coef) + 1)

plt.plot(epochs, dice_coef, 'b', label='Training dice coefficent',color="green")
plt.plot(epochs, val_dice_coef, 'b', label='Validation dice coefficient',color="blue")
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.savefig('vanilla_train_meanloss_bs64.png')

plt.plot(epochs, loss, 'b', label='Training loss',color="green")
plt.plot(epochs, val_loss, 'b', label='Validation loss',color="blue")
plt.title('Training and validation loss')
plt.legend()
plt.savefig('vanilla_loss_meanloss_bs64.png')

plt.show()

# %% [markdown]
# #### Checking the model on random images

# %%
idx = random.randint(0,len(X_train))

# %%
preds_train = model_unet.predict(X_train[:int(X_train.shape[0]*0.9)],verbose=1)
preds_val = model_unet.predict(X_train[int(X_train.shape[0]*0.9):],verbose=1)
#preds_test=model_unet.predict(X_t,verbose=1)

# %%
#Each pixel is given a value between 0 and 1. We set a threshold 0.5 to binarize using thresholding

# %%
preds_train_t = (preds_train >0.6).astype(np.uint8)
preds_val_t = (preds_val>0.6).astype(np.uint8)
#preds_test_t = (preds_test>0.6).astype(np.uint8)

# %%
#Checking

# %%
ix = random.randint(0,len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(Y_train[ix])
plt.show()
imshow(preds_train_t[ix])
plt.show()
